# %%
import pandas as pd
movie_info = pd.read_csv('../Data/movies_info_original.csv')

# %%
movie_info
# Out:
#               ASIN  ...                            Genres
# 0       B003AI2VGA  ...                             Drama
# 1       B00006HAXW  ...                               NaN
# 2       B00004CQT3  ...                               NaN
# 3       B00004CQT4  ...                               NaN
# 4       B006JIUN2W  ...                              Kids
# ...            ...  ...                               ...
# 233126  B003S1UNZU  ...                               NaN
# 233127  B000GRUN4A  ...                               NaN
# 233128  B003F32YGC  ...                               NaN
# 233129  B003A3PGF8  ...  Arts, Entertainment, and Culture
# 233130  6304952198  ...                               NaN
#
# [233131 rows x 13 columns]

# %%
unextract_title_movie_id = movie_info[movie_info['Title'].isnull()]

# %%
unextract_title_movie_id['ASIN'].to_csv('../Data/unextract_title_movie_id.csv',index=False,sep=',')
